# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('Profile list - result.csv')

# %%
df.tail()
# Out:
#                                             profileUrl               fullName  \
# 371  https://www.linkedin.com/in/carlos-andres-schm...  Carlos Andres Schmidt
# 372          https://www.linkedin.com/in/rombachhayley         Hayley Rombach
# 373            https://www.linkedin.com/in/chrystalkim           Chrystal Kim
# 374             https://www.linkedin.com/in/kellywu101                Kelly W
# 375  https://www.linkedin.com/in/anudeep-rastogi-92...        Anudeep Rastogi
#
#     firstName        lastName  \
# 371    Carlos  Andres Schmidt
# 372    Hayley         Rombach
# 373  Chrystal             Kim
# 374     Kelly               W
# 375   Anudeep         Rastogi
#
#                                        profileImageUrl  \
# 371  https://media.licdn.com/dms/image/C4E03AQHekP7...
# 372  https://media.licdn.com/dms/image/C4D03AQHYR7f...
# 373  https://media.licdn.com/dms/image/D5603AQFMvNR...
# 374                                                NaN
# ...

# %%
df['Company'] = np.nan

# %%
for i in range(len(df)):
  a = "Data Scientist"
  if a in df['query'][i]:
    df['Company'][i] = df['query'][i].replace('Data Scientist','').replace(' ','')
  else:
    df['Company'][i] = df['query'][i].replace('Recruiter','').replace(' ','')
# Out:
# <ipython-input-9-663b67102b26>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company'][i] = df['query'][i].replace('Data Scientist','').replace(' ','')

# %%
df.tail()
# Out:
#                                             profileUrl               fullName  \
# 371  https://www.linkedin.com/in/carlos-andres-schm...  Carlos Andres Schmidt
# 372          https://www.linkedin.com/in/rombachhayley         Hayley Rombach
# 373            https://www.linkedin.com/in/chrystalkim           Chrystal Kim
# 374             https://www.linkedin.com/in/kellywu101                Kelly W
# 375  https://www.linkedin.com/in/anudeep-rastogi-92...        Anudeep Rastogi
#
#     firstName        lastName  \
# 371    Carlos  Andres Schmidt
# 372    Hayley         Rombach
# 373  Chrystal             Kim
# 374     Kelly               W
# 375   Anudeep         Rastogi
#
#                                        profileImageUrl  \
# 371  https://media.licdn.com/dms/image/C4E03AQHekP7...
# 372  https://media.licdn.com/dms/image/C4D03AQHYR7f...
# 373  https://media.licdn.com/dms/image/D5603AQFMvNR...
# 374                                                NaN
# ...

# %%
df.columns
# Out:
# Index(['profileUrl', 'fullName', 'firstName', 'lastName', 'profileImageUrl',
#        'currentJob', 'connectionDegree', 'job', 'location',
#        'sharedConnections', 'url', 'name', 'query', 'category', 'timestamp',
#        'additionalInfo', 'pastJob', 'error', 'summary', 'certifications',
#        'Company'],
#       dtype='object')

# %%
df.drop(['profileUrl', 'profileImageUrl',
       'currentJob', 'connectionDegree',
       'sharedConnections', 'url', 'name', 'category', 'timestamp',
       'additionalInfo', 'pastJob', 'error', 'summary', 'certifications'
       ],inplace=True,axis=1)

# %%
df.head(30)
# Out:
#                    fullName    firstName        lastName  \
# 0           Chris Goldammer        Chris       Goldammer
# 1                Zhiying Gu      Zhiying              Gu
# 2                 Jiayun D.       Jiayun              D.
# 3                  Sujin Oh        Sujin              Oh
# 4             Totte Harinen        Totte         Harinen
# 5            Yanqing Duanmu      Yanqing          Duanmu
# 6                   Yadi Li         Yadi              Li
# 7             Animesh Goyal      Animesh           Goyal
# 8              Aditya Patil       Aditya           Patil
# 9   Niyousha Mohammadshafie     Niyousha  Mohammadshafie
# 10            Kathleen Lara     Kathleen            Lara
# 11                  Cole B.         Cole              B.
# 12                   Lea Z.          Lea              Z.
# 13               Ling Jiang         Ling           Jiang
# 14             Rohan Joseph        Rohan          Joseph
# ...

# %%
df['firstName'][1][0]
# Out:
# 'Z'

# %%
df['mail_id'] = np.nan

# %%
for i in range(len(df)):
  if df['Company'][i] == 'Google':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}{df['lastName'][i].lower()}@{'Google.com'}"
  elif df['Company'][i] == 'Microsoft':
    df['mail_id'][i] = f"{df['firstName'][i][0].lower()}{df['lastName'][i].lower()}@{'Microsoft.com'}"
  elif df['Company'][i] == 'Airbnb':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'airbnb.com'}"
  elif df['Company'][i] == 'Apple':
    df['mail_id'][i] = f"{df['firstName'][i][0].lower()}{df['lastName'][i].lower()}@{'apple.com'}"
  elif df['Company'][i] == 'FidelityInvestments':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'fidelity.com'}"
  elif df['Company'][i] == 'Linkedin':
    df['mail_id'][i] = f"{df['firstName'][i][0].lower()}{df['lastName'][i].lower()}@{'linkedin.com'}"
  elif df['Company'][i] == 'Netflix':
    df['mail_id'][i] = f"{df['firstName'][i][0].lower()}{df['lastName'][i].lower()}@{'netlfix.com'}"
  elif df['Company'][i] == 'AmericanExpress':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'americanexpress.com'}"
  elif df['Company'][i] == 'IBM':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'ibm.com'}"
  elif df['Company'][i] == 'Adobe':
    df['mail_id'][i] = f"{df['firstName'][i][0].lower()}{df['lastName'][i].lower()}@{'adobe.com'}"
  elif df['Company'][i] == 'Nvidia':
    df['mail_id'][i] = f"{df['firstName'][i][0].lower()}{df['lastName'][i].lower()}@{'nvidia.com'}"
  elif df['Company'][i] == 'AMD':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'amd.com'}"
  elif df['Company'][i] == 'ScaleAI':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}@{'scale.com'}"
  elif df['Company'][i] == 'PerplexityAI':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}@{'perplexity.ai'}"
  elif df['Company'][i] == 'JPMorgan':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'jpmorgan.com'}"
  elif df['Company'][i] == 'Morganstanley':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'morganstanley.com'}"
  elif df['Company'][i] == 'Quantumblack':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'quantumblack.com'}"
  elif df['Company'][i] == 'Meta':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}{df['lastName'][i].lower()}@{'meta.com'}"
  elif df['Company'][i] == 'Pepsico':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'pepsico.com'}"
  elif df['Company'][i] == 'Amazon':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}{df['lastName'][i].lower()}@{'amazon.com'}"
  elif df['Company'][i] == 'GoldmanSachs':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'gs.com'}"
  elif df['Company'][i] == 'Mckinsey':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}_{df['lastName'][i].lower()}@{'mckinsey.com'}"
  elif df['Company'][i] == 'MckinseyTechnical':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}_{df['lastName'][i].lower()}@{'mckinsey.com'}"
  elif df['Company'][i] == 'GoldmanSachsTechnical':
    df['mail_id'][i] = f"{df['firstName'][i].lower()}.{df['lastName'][i].lower()}@{'gs.com'}"

# %%
df.head(1000)
# Out:
#                                fullName      firstName  \
# 0                       Chris Goldammer          Chris
# 1                            Zhiying Gu        Zhiying
# 2                             Jiayun D.         Jiayun
# 3                              Sujin Oh          Sujin
# 4                         Totte Harinen          Totte
# 5                        Yanqing Duanmu        Yanqing
# 6                               Yadi Li           Yadi
# 7                         Animesh Goyal        Animesh
# 8                          Aditya Patil         Aditya
# 9               Niyousha Mohammadshafie       Niyousha
# 10                        Kathleen Lara       Kathleen
# 11                              Cole B.           Cole
# 12                               Lea Z.            Lea
# 13                           Ling Jiang           Ling
# 14                         Rohan Joseph          Rohan
# 15                      Pragya Bhandari         Pragya
# ...
